# %% [markdown]
# 31-3-2026 1,2-4-2026

# %%
#31st
#pandas

# %%
#country GDP or economy analysis

# %%
import pandas as pd
# we are importing pandas library as pd

# %%
pd.__version__
# to check the version of pandas library
# Out:
# '3.0.2'

# %%
df = pd.read_excel(r"C:\\Users\\tadak\\Downloads\\NIT\\data.xlsx")
# to read the excel file and store it in a dataframe called df

# %%
df
# to display the dataframe df
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ..                   ...
# ...

# %%
len(df)
# Out:
# 195

# %%
df.shape
# to check the number of rows and columns in the dataframe df
# Out:
# (195, 5)

# %%
df.columns
# Out:
# Index(['CountryName', 'CountryCode', 'BirthRate', 'InternetUsers',
#        'IncomeGroup'],
#       dtype='str')

# %%
len(df.columns)
# Out:
# 5

# %%
df.isnull() 
# to check for any missing values in the dataframe df
# Out:
#      CountryName  CountryCode  BirthRate  InternetUsers  IncomeGroup
# 0          False        False      False          False        False
# 1          False        False      False          False        False
# 2          False        False      False          False        False
# 3          False        False      False          False        False
# 4          False        False      False          False        False
# ..           ...          ...        ...            ...          ...
# 190        False        False      False          False        False
# 191        False        False      False          False        False
# 192        False        False      False          False        False
# 193        False        False      False          False        False
# 194        False        False      False          False        False
#
# [195 rows x 5 columns]

# %%
df.isna()
# to check for any missing values in the dataframe df
# Out:
#      CountryName  CountryCode  BirthRate  InternetUsers  IncomeGroup
# 0          False        False      False          False        False
# 1          False        False      False          False        False
# 2          False        False      False          False        False
# 3          False        False      False          False        False
# 4          False        False      False          False        False
# ..           ...          ...        ...            ...          ...
# 190        False        False      False          False        False
# 191        False        False      False          False        False
# 192        False        False      False          False        False
# 193        False        False      False          False        False
# 194        False        False      False          False        False
#
# [195 rows x 5 columns]

# %%
df.isnull().sum()
# to count the number of missing values in each column of the dataframe df
# Out:
# CountryName      0
# CountryCode      0
# BirthRate        0
# InternetUsers    0
# IncomeGroup      0
# dtype: int64

# %%
df.info()
# to get a summary of the dataframe df, including the data types and non-null counts of each column
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   CountryName    195 non-null    str
#  1   CountryCode    195 non-null    str
#  2   BirthRate      195 non-null    float64
#  3   InternetUsers  195 non-null    float64
#  4   IncomeGroup    195 non-null    str
# dtypes: float64(2), str(3)
# memory usage: 12.9 KB

# %%
type(df)
# Out:
# pandas.DataFrame

# %%
id(df)
# Out:
# 2060451288256

# %%
df.dtypes
# to check the data types of each column in the dataframe df
# Out:
# CountryName          str
# CountryCode          str
# BirthRate        float64
# InternetUsers    float64
# IncomeGroup          str
# dtype: object

# %%
df.head()
# to display the first 5 rows of the dataframe df
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
df.tail()
# to display the last 5 rows of the dataframe df
# Out:
#           CountryName CountryCode  BirthRate  InternetUsers  \
# 190       Yemen, Rep.         YEM     32.947           20.0
# 191      South Africa         ZAF     20.850           46.5
# 192  Congo, Dem. Rep.         COD     42.394            2.2
# 193            Zambia         ZMB     40.471           15.4
# 194          Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 190  Lower middle income
# 191  Upper middle income
# 192           Low income
# 193  Lower middle income
# 194           Low income

# %%
df.head(10)
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244        78.9000
# 1           Afghanistan         AFG     35.253         5.9000
# 2                Angola         AGO     45.985        19.1000
# 3               Albania         ALB     12.877        57.2000
# 4  United Arab Emirates         ARE     11.044        88.0000
# 5             Argentina         ARG     17.716        59.9000
# 6               Armenia         ARM     13.308        41.9000
# 7   Antigua and Barbuda         ATG     16.447        63.4000
# 8             Australia         AUS     13.200        83.0000
# 9               Austria         AUT      9.400        80.6188
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income
# 5          High income
# 6  Lower middle income
# 7          High income
# 8          High income
# 9          High income

# %%
#indexing and slicing in pandas dataframe

# %%
df[5:10]
# Out:
#            CountryName CountryCode  BirthRate  InternetUsers  \
# 5            Argentina         ARG     17.716        59.9000
# 6              Armenia         ARM     13.308        41.9000
# 7  Antigua and Barbuda         ATG     16.447        63.4000
# 8            Australia         AUS     13.200        83.0000
# 9              Austria         AUT      9.400        80.6188
#
#            IncomeGroup
# 5          High income
# 6  Lower middle income
# 7          High income
# 8          High income
# 9          High income

# %%
df[3:]
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# 5               Argentina         ARG     17.716           59.9
# 6                 Armenia         ARM     13.308           41.9
# 7     Antigua and Barbuda         ATG     16.447           63.4
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 3    Upper middle income
# 4            High income
# 5            High income
# 6    Lower middle income
# 7            High income
# ..                   ...
# ...

# %%
df[:35]
# Out:
#                  CountryName CountryCode  BirthRate  InternetUsers  \
# 0                      Aruba         ABW     10.244       78.90000
# 1                Afghanistan         AFG     35.253        5.90000
# 2                     Angola         AGO     45.985       19.10000
# 3                    Albania         ALB     12.877       57.20000
# 4       United Arab Emirates         ARE     11.044       88.00000
# 5                  Argentina         ARG     17.716       59.90000
# 6                    Armenia         ARM     13.308       41.90000
# 7        Antigua and Barbuda         ATG     16.447       63.40000
# 8                  Australia         AUS     13.200       83.00000
# 9                    Austria         AUT      9.400       80.61880
# 10                Azerbaijan         AZE     18.300       58.70000
# 11                   Burundi         BDI     44.151        1.30000
# 12                   Belgium         BEL     11.200       82.17020
# ...

# %%
df[0:200:25]
# Out:
#     CountryName CountryCode  BirthRate  InternetUsers          IncomeGroup
# 0         Aruba         ABW     10.244      78.900000          High income
# 25     Barbados         BRB     12.188      73.000000          High income
# 50      Ecuador         ECU     21.070      40.353684  Upper middle income
# 75     Honduras         HND     21.593      17.800000  Lower middle income
# 100       Libya         LBY     21.425      16.500000  Upper middle income
# 125     Namibia         NAM     29.937      13.900000  Upper middle income
# 150       Sudan         SDN     33.477      22.700000  Lower middle income
# 175     Tunisia         TUN     19.800      43.800000  Upper middle income

# %%
df[::50]
# Out:
#     CountryName CountryCode  BirthRate  InternetUsers          IncomeGroup
# 0         Aruba         ABW     10.244      78.900000          High income
# 50      Ecuador         ECU     21.070      40.353684  Upper middle income
# 100       Libya         LBY     21.425      16.500000  Upper middle income
# 150       Sudan         SDN     33.477      22.700000  Lower middle income

# %%
df[::-1]
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 194              Zimbabwe         ZWE     35.715           18.5
# 193                Zambia         ZMB     40.471           15.4
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 191          South Africa         ZAF     20.850           46.5
# 190           Yemen, Rep.         YEM     32.947           20.0
# ..                    ...         ...        ...            ...
# 4    United Arab Emirates         ARE     11.044           88.0
# 3                 Albania         ALB     12.877           57.2
# 2                  Angola         AGO     45.985           19.1
# 1             Afghanistan         AFG     35.253            5.9
# 0                   Aruba         ABW     10.244           78.9
#
#              IncomeGroup
# 194           Low income
# 193  Lower middle income
# 192           Low income
# 191  Upper middle income
# 190  Lower middle income
# ..                   ...
# ...

# %%
df[::-50]
# Out:
#           CountryName CountryCode  BirthRate  InternetUsers  \
# 194          Zimbabwe         ZWE     35.715        18.5000
# 144  French Polynesia         PYF     16.393        56.8000
# 94           Kiribati         KIR     29.044        11.5000
# 44     Czech Republic         CZE     10.200        74.1104
#
#              IncomeGroup
# 194           Low income
# 144          High income
# 94   Lower middle income
# 44           High income

# %%
# April 1st

# %%
df.columns
# Out:
# Index(['CountryName', 'CountryCode', 'BirthRate', 'InternetUsers',
#        'IncomeGroup'],
#       dtype='str')

# %%
df["CountryName"]
# to access the "CountryName" column of the dataframe df
# Out:
# 0                     Aruba
# 1               Afghanistan
# 2                    Angola
# 3                   Albania
# 4      United Arab Emirates
#                ...
# 190             Yemen, Rep.
# 191            South Africa
# 192        Congo, Dem. Rep.
# 193                  Zambia
# 194                Zimbabwe
# Name: CountryName, Length: 195, dtype: str

# %%
df[['CountryCode',"BirthRate"]]
# to access the "CountryCode" and "BirthRate" columns of the dataframe df
# Out:
#     CountryCode  BirthRate
# 0           ABW     10.244
# 1           AFG     35.253
# 2           AGO     45.985
# 3           ALB     12.877
# 4           ARE     11.044
# ..          ...        ...
# 190         YEM     32.947
# 191         ZAF     20.850
# 192         COD     42.394
# 193         ZMB     40.471
# 194         ZWE     35.715
#
# [195 rows x 2 columns]

# %%
#split the data into catogorical and numerical parts

# %%
df.head(1)
# Out:
#   CountryName CountryCode  BirthRate  InternetUsers  IncomeGroup
# 0       Aruba         ABW     10.244           78.9  High income

# %%
df.columns
# Out:
# Index(['CountryName', 'CountryCode', 'BirthRate', 'InternetUsers',
#        'IncomeGroup'],
#       dtype='str')

# %%
df_cat = df[['CountryName', 'CountryCode','IncomeGroup']]
df_cat.head(1)
# to create a new dataframe df_cat that contains only the categorical columns "CountryName", "CountryCode", and "IncomeGroup" from the original dataframe df, and then display the first row of df_cat
# Out:
#   CountryName CountryCode  IncomeGroup
# 0       Aruba         ABW  High income

# %%
df_num = df[['BirthRate', 'InternetUsers']]
df_num.head(1)
# to create a new dataframe df_num that contains only the numerical columns "BirthRate" and "InternetUsers" from the original dataframe df, and then display the first row of df_num
# Out:
#    BirthRate  InternetUsers
# 0     10.244           78.9

# %%
print(df.shape)
print(df_cat.shape)
print(df_num.shape)
# to check the number of rows and columns in the original dataframe df, the categorical dataframe df_cat, and the numerical dataframe df_num
# Out:
# (195, 5)
# (195, 3)
# (195, 2)

# %%
print(df.columns)
print()
print(df_cat.columns)
print()
print(df_num.columns)
# Out:
# Index(['CountryName', 'CountryCode', 'BirthRate', 'InternetUsers',
#        'IncomeGroup'],
#       dtype='str')
#
# Index(['CountryName', 'CountryCode', 'IncomeGroup'], dtype='str')
#
# Index(['BirthRate', 'InternetUsers'], dtype='str')

# %%
df.describe() #stats func for nuemerical data
# Out:
#         BirthRate  InternetUsers
# count  195.000000     195.000000
# mean    21.469928      42.076471
# std     10.605467      29.030788
# min      7.900000       0.900000
# 25%     12.120500      14.520000
# 50%     19.680000      41.000000
# 75%     29.759500      66.225000
# max     49.661000      96.546800

# %%
df_num.describe()
# to get the summary statistics of the numerical dataframe df_num, including count, mean, standard deviation, minimum, 25th percentile, median, 75th percentile, and maximum values for each numerical column
# Out:
#         BirthRate  InternetUsers
# count  195.000000     195.000000
# mean    21.469928      42.076471
# std     10.605467      29.030788
# min      7.900000       0.900000
# 25%     12.120500      14.520000
# 50%     19.680000      41.000000
# 75%     29.759500      66.225000
# max     49.661000      96.546800

# %%
df_cat.describe()
# to get the summary statistics of the categorical dataframe df_cat, including count, unique values, top value, and frequency for each categorical column
# Out:
#        CountryName CountryCode  IncomeGroup
# count          195         195          195
# unique         195         195            4
# top          Aruba         ABW  High income
# freq             1           1           67

# %%
#filtering in pandas

# %%
df['InternetUsers'] < 2
# to create a boolean mask that identifies the rows in the dataframe df where the "InternetUsers" column has values less than 2
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 190    False
# 191    False
# 192    False
# 193    False
# 194    False
# Name: InternetUsers, Length: 195, dtype: bool

# %%
df[df['InternetUsers'] < 2]
# to filter the dataframe df and return only the rows where the "InternetUsers" column has values less than 2
# Out:
#       CountryName CountryCode  BirthRate  InternetUsers          IncomeGroup
# 11        Burundi         BDI     44.151            1.3           Low income
# 52        Eritrea         ERI     34.800            0.9           Low income
# 55       Ethiopia         ETH     32.925            1.9           Low income
# 64         Guinea         GIN     37.337            1.6           Low income
# 117       Myanmar         MMR     18.119            1.6  Lower middle income
# 127         Niger         NER     49.661            1.7           Low income
# 154  Sierra Leone         SLE     36.729            1.7           Low income
# 156       Somalia         SOM     43.891            1.5           Low income
# 172   Timor-Leste         TLS     35.755            1.1  Lower middle income

# %%
len(df[df['InternetUsers'] < 2])
# Out:
# 9

# %%
df[df['BirthRate'] > 40]
# to filter the dataframe df and return only the rows where the "BirthRate" column has values greater than 40
# Out:
#           CountryName CountryCode  BirthRate  InternetUsers  \
# 2              Angola         AGO     45.985           19.1
# 11            Burundi         BDI     44.151            1.3
# 14       Burkina Faso         BFA     40.551            9.1
# 65        Gambia, The         GMB     42.525           14.0
# 115              Mali         MLI     44.138            3.5
# 127             Niger         NER     49.661            1.7
# 128           Nigeria         NGA     40.045           38.0
# 156           Somalia         SOM     43.891            1.5
# 167              Chad         TCD     45.745            2.3
# 178            Uganda         UGA     43.474           16.2
# 192  Congo, Dem. Rep.         COD     42.394            2.2
# 193            Zambia         ZMB     40.471           15.4
#
#              IncomeGroup
# 2    Upper middle income
# 11            Low income
# 14            Low income
# 65            Low income
# 115           Low income
# 127           Low income
# ...

# %%
len(df[df['BirthRate'] > 40])
# Out:
# 12

# %%
df[(df['BirthRate'] > 40) & (df['InternetUsers'] < 2)]
# to filter the dataframe df and return only the rows where the "BirthRate" column has values greater than 40 and the "InternetUsers" column has values less than 2
# Out:
#     CountryName CountryCode  BirthRate  InternetUsers IncomeGroup
# 11      Burundi         BDI     44.151            1.3  Low income
# 127       Niger         NER     49.661            1.7  Low income
# 156     Somalia         SOM     43.891            1.5  Low income

# %%
df[df.IncomeGroup == 'High income']
# to filter the dataframe df and return only the rows where the "IncomeGroup" column has the value "High income"
# Out:
#                CountryName CountryCode  BirthRate  InternetUsers  IncomeGroup
# 0                    Aruba         ABW     10.244          78.90  High income
# 4     United Arab Emirates         ARE     11.044          88.00  High income
# 5                Argentina         ARG     17.716          59.90  High income
# 7      Antigua and Barbuda         ATG     16.447          63.40  High income
# 8                Australia         AUS     13.200          83.00  High income
# ..                     ...         ...        ...            ...          ...
# 174    Trinidad and Tobago         TTO     14.590          63.80  High income
# 180                Uruguay         URY     14.374          57.69  High income
# 181          United States         USA     12.500          84.20  High income
# 184          Venezuela, RB         VEN     19.842          54.90  High income
# 185  Virgin Islands (U.S.)         VIR     10.700          45.30  High income
#
# [67 rows x 5 columns]

# %%
df['IncomeGroup'].unique()
# to get the unique values in the "IncomeGroup" column of the dataframe df
# Out:
# <ArrowStringArray>
# ['High income', 'Low income', 'Upper middle income', 'Lower middle income']
# Length: 4, dtype: str

# %%
df['IncomeGroup'].nunique()
# to get the number of unique values in the "IncomeGroup" column of the dataframe df
# Out:
# 4

# %%
df.columns = ['a','b','c','d','e']
# to rename the columns of the dataframe df to 'a', 'b', 'c', 'd', and 'e'

# %%
df.columns
# Out:
# Index(['a', 'b', 'c', 'd', 'e'], dtype='str')

# %%
df.columns = ['CountryName', 'CountryCode', 'BirthRate', 'InternetUsers','IncomeGroup']

# %%
df.head(2)
# Out:
#    CountryName CountryCode  BirthRate  InternetUsers  IncomeGroup
# 0        Aruba         ABW     10.244           78.9  High income
# 1  Afghanistan         AFG     35.253            5.9   Low income

# %%
df['myCalc'] = df.BirthRate * df.InternetUsers
# to create a new column called "myCalc" in the dataframe df that is the product of the "BirthRate" and "InternetUsers" columns

# %%
df.head(3)
# Out:
#    CountryName CountryCode  BirthRate  InternetUsers          IncomeGroup  \
# 0        Aruba         ABW     10.244           78.9          High income
# 1  Afghanistan         AFG     35.253            5.9           Low income
# 2       Angola         AGO     45.985           19.1  Upper middle income
#
#      myCalc
# 0  808.2516
# 1  207.9927
# 2  878.3135

# %%
df.columns
# Out:
# Index(['CountryName', 'CountryCode', 'BirthRate', 'InternetUsers',
#        'IncomeGroup', 'myCalc'],
#       dtype='str')

# %%
# asis is 0 for rows and columns is 1
# to drop the "myCalc" column from the dataframe df, where axis=1 indicates that we are dropping a column (as opposed to a row)

# %%
df = df.drop('myCalc',axis = 1)
# to drop the "myCalc" column from the dataframe df, where axis=1 indicates that we are dropping a column (as opposed to a row)

# %%
df
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ..                   ...
# ...

# %%
# 2nd April

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
plt.rcParams['figure.figsize'] = 6,2

import warnings
warnings.filterwarnings('ignore') #os error

# %%
df["InternetUsers"]
# Out:
# 0      78.9
# 1       5.9
# 2      19.1
# 3      57.2
# 4      88.0
#        ...
# 190    20.0
# 191    46.5
# 192     2.2
# 193    15.4
# 194    18.5
# Name: InternetUsers, Length: 195, dtype: float64

# %%
vis1 = sns.distplot(df["InternetUsers"])

# %%
vis2 = sns.displot(df["InternetUsers"])

# %%
vis3 = sns.distplot(df["InternetUsers"],bins = 15)

# %%
vis4 = sns.boxplot(data = df, x = "IncomeGroup", y = "BirthRate") #BI - VARIATE ANALYSIS

# %%
# outliers are present in the low income group and high income group but not in the upper middle income group
# outliers in statistics is a data point far from the other observations in the data, which can significantly affect the results of statistical analyses and models.
# outilers also called as anomalies
# these outliers impact the machine learning model's accuracy and performance.
# to adujust these outliers we will introduce probability concepts

# %%
vis5 = sns.lmplot(data = df, x = "InternetUsers", y = "BirthRate")

# %%
vis6 = sns.lmplot(data = df, x = "InternetUsers", y = "BirthRate", fit_reg= False, hue = "IncomeGroup") 
#hue - parameter for color

# %%
vis7 = sns.lmplot(data = df, x = "InternetUsers", y = "BirthRate", fit_reg= True, hue = "IncomeGroup") 
#hue - parameter for color
