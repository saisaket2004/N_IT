# %%
t = () 
t
# Out:
# ()

# %%
type(t)
# Out:
# tuple

# %%
t1 = (10, 20, 30)
t1
# Out:
# (10, 20, 30)

# %%
#Tuple has 2 inBuilt functions
#1. count() - It counts the number of times a specified value occurs in a tuple.
#2. index() - It searches the tuple for a specified value and returns the position of where it was found.

# %%
t1.count(10)
# Out:
# 1

# %%
t1.count(100)
# Out:
# 0

# %%
t1
# Out:
# (10, 20, 30)

# %%
t1.index(10)
# Out:
# 0

# %%
t1.index(111)
# we get error because 111 is not present in the tuple t1. The index() method raises a ValueError if the specified value is not found in the tuple.
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 t1.index(111)
#       2 # we get error because 111 is not present in the tuple t1. The index() method raises a ValueError if the specified value is not found in the tuple.
#
# ValueError: tuple.index(x): x not in tuple

# %%
t1
# Out:
# (10, 20, 30)

# %%
t1[0] = 100 
#Tuples are immutable, which means that once a tuple is created, its elements cannot be modified. That is why we get a TypeError when we try to assign a new value
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 t1[0] = 100
#       2 #Tuples are immutable, which means that once a tuple is created, its elements cannot be modified. That is why we get a TypeError when we try to assign a new value
#
# TypeError: 'tuple' object does not support item assignment

# %%
# Tuples can contain elements of different data types, including integers, strings, and even other tuples.
sbi = (1234, 'cizps')
sbi
# Out:
# (1234, 'cizps')

# %%
t1*2
#When we multiply a tuple by an integer n, it creates a new tuple that contains the elements of the original tuple repeated n times. In this case, t1*2 creates a new tuple that contains the elements of t1 repeated twice, resulting in (10, 20, 30, 10, 20, 30).
# Out:
# (10, 20, 30, 10, 20, 30)

# %%
tup4 = ('one','two' , "three")

# %%
tup7 = ('Asif', 25 ,[50, 100],[150, 90] , {'John' , 'David'} , (99,22,33))

# %%
len(tup7) #Length of list
# Out:
# 6

# %%
tup4[0][0]
 # Nested indexing - Access the first character of the first tuple ele ment 'one' in tup4. The first index [0] accesses the first element of the tuple, which is the string 'one', and the second index [0] accesses the first character of that string, which is 'o'.
# Out:
# 'o'

# %%
tup4[-1] # Last item of the tuple
# Out:
# 'three'

# %%
tup7[0:3]
# Out:
# ('Asif', 25, [50, 100])

# %%
tup7[-3:] # Return last three items
# Out:
# ([150, 90], {'David', 'John'}, (99, 22, 33))

# %%
tup7[-2:] # Return last two items
# Out:
# ({'David', 'John'}, (99, 22, 33))

# %%
del tup4[0] # Tuples are immutable which means we can't DELETE tuple items
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 del tup4[0] # Tuples are immutable which means we can't DELETE tuple items
#
# TypeError: 'tuple' object doesn't support item deletion

# %%
del tup4 # Deleting entire tuple object is possible

# %%
for i in tup7: 
    print(i)
# Out:
# Asif
# 25
# [50, 100]
# [150, 90]
# {'John', 'David'}
# (99, 22, 33)

# %%
for i in enumerate(tup7): 
    print(i)
# Out:
# (0, 'Asif')
# (1, 25)
# (2, [50, 100])
# (3, [150, 90])
# (4, {'John', 'David'})
# (5, (99, 22, 33))

# %%
mytuple = ('one', 'two', 'three', 'four', 'five', 'six', 'seven', 'eight')

# %%
'one' in mytuple # Check if 'one' exist in the list
# Out:
# True

# %%
'ten' in mytuple # Check if 'ten' exist in the list
# Out:
# False

# %%
if 'three' in mytuple:
    print("Three Exists")
else:
    print("Three Does not exist")
# Out:
# Three Exists

# %%
if 'eleven' in mytuple: # Check if 'eleven' exist in the list 
    print('eleven is present in the tuple') 
else: 
    print('eleven is not present in the tuple')
# Out:
# eleven is not present in the tuple

# %%
mytuple2 = (43,67,99,12,6,90,67)

# %%
sorted(mytuple2) # Sort the tuple in ascending order. The sorted() function returns a new sorted list from the items in the iterable (in this case, the tuple mytuple2). The original tuple remains unchanged.
# Out:
# [6, 12, 43, 67, 67, 90, 99]

# %%
sorted(mytuple2, reverse=True) # Sort in descending order
# Out:
# [99, 90, 67, 67, 43, 12, 6]
