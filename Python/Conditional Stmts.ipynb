# %% [markdown]
# #2,3-4-2026

# %%
# condition statments 
#if 
#else
#nested if 
#if elif else

# %%
if True: # indentiation is always 4 spaces
    print('Data Science')
# Out:
# Data Science

# %%
if True: # indentiation is always 4 spaces
print('Data Science')

# get error because of indentation error.

# %%
if True: # indentiation is always 4 spaces
 print('Data Science')
# Out:
# Data Science

# %%
if False:
    print('Data Science')
print('bye for now')
# Out:
# bye for now

# %%
if True:
    print('Data Science')
print('bye for now')
# Out:
# Data Science
# bye for now

# %%
if True:
    print('Data Science')
else:
    print('bye for now')
# Out:
# Data Science

# %%
# check the number is even number or odd number 
x = 4
r = x % 2 

if r == 0:
    print('Even number')
# Out:
# Even number

# %%
x = 5
r = x % 2 

if r == 0:
    print('Even number')

# no output and no error because the condition is false.

# %%
x = 5
r = x % 2 

if r == 0:
    print('Even number')

if r == 1:
    print('odd number')
# Out:
# odd number

# %%
x = 6
r = x % 2 

if r == 0:
    print('Even number')
if r == 1:
    print('odd number')
# Out:
# Even number

# %%
x = 7
r = x % 2 

if r == 0:
    print('Even number')
else:
    print('odd number') 

# we donot use multiple if statement because it is not efficient. we use if else statement.
# Out:
# odd number

# %%
# nested if 

x = 3
r = x % 2

if r == 0:
    print('Even number')
    if x>5:
        print('greater number')
  
else:
    print('Odd Number')
# Out:
# Odd Number

# %%
# nested if 

x = 4
r = x % 2

if r == 0:
    print('Even number')
    if x>5:
        print('greater number')
  
else:
    print('Odd Number')
# Out:
# Even number

# %%
# nested if 

x = 4
r = x % 2

if r == 0:
    print('Even number')
    
    if x>5:
        print('greater number')
    else:
        print('lesser number')
  
else:
    print('Odd Number')
# Out:
# Even number
# lesser number

# %%
# nested if 

x = 14
r = x % 2

if r == 0:
    print('Even number')
    
    if x>5:
        print('greater number')
    else:
        print('lesser number')
  
else:
    print('Odd Number')
# Out:
# Even number
# greater number

# %%
x = 3

if x == 1:
    print('one')
if x == 2:
    print('Two')
if x == 3:
    print('Three')
if x == 4:
    print('four')
# Out:
# Three

# %%
#elif
x = 3

if x == 1:
    print('one')
elif x == 2:
    print('Two')
elif x == 3:
    print('Three')
elif x == 4:
    print('four')

# we use elif statement because it is more efficient than multiple if statement.
# Out:
# Three

# %%
x = 10

if x == 1:
    print('one')
    
elif x == 2:
    print('Two')
elif x == 3:
    print('Three')
elif x == 4:
    print('four')

else:
    print('number not found')
# Out:
# number not found

# %%
age = 19
if age > 18: print("Eligible to Vote.")
# Out:
# Eligible to Vote.
